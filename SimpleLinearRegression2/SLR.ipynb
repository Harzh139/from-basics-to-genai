# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#Read The dataset
df = pd.read_csv('height-weight.csv')

# %%
plt.scatter(df.Weight,df.Height)
plt.xlabel('Weight')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
#Problem: predict height based on weight
X = df[['Weight']]
y = df.Height

# %%
#train_test_split
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test =train_test_split(X,y,test_size=0.2,random_state=1)

# %%
#Scaling >>>> Standarization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, model.predict(X_train), color='red')  # Regression line
plt.xlabel('Weight (standardized)')
plt.ylabel('Height')
plt.title('Linear Regression Fit (Training Data)')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
#Linear regression parameters 
#fit_intercept >>> The best fit line will have intercept , by default True
#copy_x >>> copy the X_train and thn build the model,it will not modify the original data
#n_jobs >>>> -1 means all processors
#positive >>>> when set to true force the coeff to be positive


#fit>> train the model
#predict >> test the model


#coef_
#intercept_
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(f'The coeff of model is {model.coef_} and intercept is {model.intercept_}')
# Out:
# The coeff of model is [17.73635106] and intercept is 158.88888888888889

# %%
#Prediction
y_pred = model.predict(X_test)

# %%
plt.scatter(X_train , y_train)
plt.plot(X_test ,y_pred)

# %%
#Performance metric
from sklearn.metrics import mean_squared_error , mean_absolute_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 4.179973432576941

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 28.276946048811993

# %%
rsqr = r2_score(y_test,y_pred)
